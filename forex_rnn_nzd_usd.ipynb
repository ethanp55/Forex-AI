# %%
# Install talib for technical indicators
# %%capture will suppress all output - these commands produce way too many
#   output statments
# %%capture
! wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
! tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
! ./configure --prefix=/usr
! make
! make install
! pip install Ta-Lib

# %%
! pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 2.7MB/s
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.17.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.18.5)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.23.2 threadpoolctl-2.1.0

# %% [markdown]
# ### Imports and file path

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import talib
import tensorflow as tf
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization, Input, Conv2D, MaxPool2D, concatenate, Activation, add, AveragePooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras import Model
import json
import time
from collections import deque
import warnings
from sklearn.preprocessing import StandardScaler
from pickle import dump, load

file_path = '/content/drive/My Drive/Forex_Robot/'

# %%
# Mount google drive for accessing files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Read in and clean/prepare data

# %%
df = pd.read_csv(file_path + 'Oanda_Nzd_Usd_M30.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

df
# Out:
#                       Date  ...  Nonfarm_Payroll_Previous
# 0      2008-03-09 19:00:00  ...                    -17000
# 1      2008-03-09 19:30:00  ...                    -17000
# 2      2008-03-09 20:00:00  ...                    -17000
# 3      2008-03-09 20:30:00  ...                    -17000
# 4      2008-03-09 21:00:00  ...                    -17000
# ...                    ...  ...                       ...
# 159151 2020-10-22 17:30:00  ...                   1489000
# 159152 2020-10-22 18:00:00  ...                   1489000
# 159153 2020-10-22 18:30:00  ...                   1489000
# 159154 2020-10-22 19:00:00  ...                   1489000
# 159155 2020-10-22 19:30:00  ...                   1489000
#
# [159156 rows x 12 columns]

# %%
# Add hour of day, day of week, and month of year (for additional features)
# Use sine and cosine to keep the cyclic nature of hour, day, and month
#  (December is closer to January than October, midnight is closer to 1 am than
#  10 pm, etc.)
df['sin_hour'] = np.sin(2 * np.pi * df['Date'].dt.hour / 24)
df['cos_hour'] = np.cos(2 * np.pi * df['Date'].dt.hour / 24)
df['sin_day'] = np.sin(2 * np.pi * df['Date'].dt.day / 7)
df['cos_day'] = np.cos(2 * np.pi * df['Date'].dt.day / 7)
df['sin_month'] = np.sin(2 * np.pi * df['Date'].dt.month / 12)
df['cos_month'] = np.cos(2 * np.pi * df['Date'].dt.month / 12)

# Plots to illustrate cyclic nature of time
df.sin_month.plot()
df.cos_month.plot()

# Show the updated dataframe
df.head()
# Out:
#                  Date  Bid_Open  Bid_High  ...   cos_day  sin_month     cos_month
# 0 2008-03-09 19:00:00   0.79185   0.79190  ... -0.222521        1.0  6.123234e-17
# 1 2008-03-09 19:30:00   0.79155   0.79245  ... -0.222521        1.0  6.123234e-17
# 2 2008-03-09 20:00:00   0.79225   0.79305  ... -0.222521        1.0  6.123234e-17
# 3 2008-03-09 20:30:00   0.79280   0.79330  ... -0.222521        1.0  6.123234e-17
# 4 2008-03-09 21:00:00   0.79295   0.79310  ... -0.222521        1.0  6.123234e-17
#
# [5 rows x 18 columns]

# %%
# Add technical indicators (for additional features)
# Bid technical indicators
df['Bid_SMA1'] = talib.SMA(df['Bid_Close'], timeperiod=10)
df['Bid_SMA1_Envelope_Upper'] = df['Bid_SMA1'] + (0.1 * df['Bid_SMA1'])
df['Bid_SMA1_Envelope_Lower'] = df['Bid_SMA1'] - (0.1 * df['Bid_SMA1'])
df['Bid_EMA1'] = talib.EMA(df['Bid_Close'], timeperiod=10)
df['Bid_EMA1_Envelope_Upper'] = df['Bid_EMA1'] + (0.1 * df['Bid_EMA1'])
df['Bid_EMA1_Envelope_Lower'] = df['Bid_EMA1'] - (0.1 * df['Bid_EMA1'])
df['Bid_SMA2'] = talib.SMA(df['Bid_Close'], timeperiod=20)
df['Bid_SMA2_Envelope_Upper'] = df['Bid_SMA2'] + (0.1 * df['Bid_SMA2'])
df['Bid_SMA2_Envelope_Lower'] = df['Bid_SMA2'] - (0.1 * df['Bid_SMA2'])
df['Bid_EMA2'] = talib.EMA(df['Bid_Close'], timeperiod=20)
df['Bid_EMA2_Envelope_Upper'] = df['Bid_EMA2'] + (0.1 * df['Bid_EMA2'])
df['Bid_EMA2_Envelope_Lower'] = df['Bid_EMA2'] - (0.1 * df['Bid_EMA2'])
df['Bid_SMA3'] = talib.SMA(df['Bid_Close'], timeperiod=30)
df['Bid_SMA3_Envelope_Upper'] = df['Bid_SMA3'] + (0.1 * df['Bid_SMA3'])
df['Bid_SMA3_Envelope_Lower'] = df['Bid_SMA3'] - (0.1 * df['Bid_SMA3'])
df['Bid_EMA3'] = talib.EMA(df['Bid_Close'], timeperiod=30)
df['Bid_EMA3_Envelope_Upper'] = df['Bid_EMA3'] + (0.1 * df['Bid_EMA3'])
df['Bid_EMA3_Envelope_Lower'] = df['Bid_EMA3'] - (0.1 * df['Bid_EMA3'])
df['Bid_BB_Upper_Band'], df['Bid_BB_Middle_Band'], df['Bid_BB_Lower_Band'] = talib.BBANDS(
    df['Bid_Close'], timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
df['Bid_MACD'], df['Bid_MACD_Signal'], df['Bid_MACD_hist'] = talib.MACD(df['Bid_Close'],
                                                            fastperiod=12,
                                                            slowperiod=26,
                                                            signalperiod=9)
df['Bid_Parabollic_SAR'] = talib.SAR(df['Bid_High'], df['Bid_Low'], acceleration=0, maximum=0)
df['Bid_Slowk'], df['Bid_Slowd'] = talib.STOCH(df['Bid_High'], df['Bid_Low'], df['Bid_Close'],
                                       fastk_period=5, slowk_period=3,
                                       slowk_matype=0, slowd_period=3,
                                       slowd_matype=0)
df['Bid_RSI'] = talib.RSI(df['Bid_Close'], timeperiod=14)
df['Bid_Williams_Percent_Range'] = talib.WILLR(df['Bid_High'], df['Bid_Low'], df['Bid_Close'],
                                           timeperiod=14)
df['Bid_ADX'] = talib.ADX(df['Bid_High'], df['Bid_Low'], df['Bid_Close'], timeperiod=14)
df['Bid_ADXR'] = talib.ADXR(df['Bid_High'], df['Bid_Low'], df['Bid_Close'], timeperiod=14)
df['Bid_MOM'] = talib.MOM(df['Bid_Close'], timeperiod=10)
df['Bid_BOP'] = talib.BOP(df['Bid_Open'], df['Bid_High'], df['Bid_Low'], df['Bid_Close'])
df['Bid_AROONOSC'] = talib.AROONOSC(df['Bid_High'], df['Bid_Low'], timeperiod=14)
df['Bid_ATR'] = talib.ATR(df['Bid_High'], df['Bid_Low'], df['Bid_Close'], timeperiod=14)

# Ask technical indicators
df['Ask_SMA1'] = talib.SMA(df['Ask_Close'], timeperiod=10)
df['Ask_SMA1_Envelope_Upper'] = df['Ask_SMA1'] + (0.1 * df['Ask_SMA1'])
df['Ask_SMA1_Envelope_Lower'] = df['Ask_SMA1'] - (0.1 * df['Ask_SMA1'])
df['Ask_EMA1'] = talib.EMA(df['Ask_Close'], timeperiod=10)
df['Ask_EMA1_Envelope_Upper'] = df['Ask_EMA1'] + (0.1 * df['Ask_EMA1'])
df['Ask_EMA1_Envelope_Lower'] = df['Ask_EMA1'] - (0.1 * df['Ask_EMA1'])
df['Ask_SMA2'] = talib.SMA(df['Ask_Close'], timeperiod=20)
df['Ask_SMA2_Envelope_Upper'] = df['Ask_SMA2'] + (0.1 * df['Ask_SMA2'])
df['Ask_SMA2_Envelope_Lower'] = df['Ask_SMA2'] - (0.1 * df['Ask_SMA2'])
df['Ask_EMA2'] = talib.EMA(df['Ask_Close'], timeperiod=20)
df['Ask_EMA2_Envelope_Upper'] = df['Ask_EMA2'] + (0.1 * df['Ask_EMA2'])
df['Ask_EMA2_Envelope_Lower'] = df['Ask_EMA2'] - (0.1 * df['Ask_EMA2'])
df['Ask_SMA3'] = talib.SMA(df['Ask_Close'], timeperiod=30)
df['Ask_SMA3_Envelope_Upper'] = df['Ask_SMA3'] + (0.1 * df['Ask_SMA3'])
df['Ask_SMA3_Envelope_Lower'] = df['Ask_SMA3'] - (0.1 * df['Ask_SMA3'])
df['Ask_EMA3'] = talib.EMA(df['Ask_Close'], timeperiod=30)
df['Ask_EMA3_Envelope_Upper'] = df['Ask_EMA3'] + (0.1 * df['Ask_EMA3'])
df['Ask_EMA3_Envelope_Lower'] = df['Ask_EMA3'] - (0.1 * df['Ask_EMA3'])
df['Ask_BB_Upper_Band'], df['Ask_BB_Middle_Band'], df['Ask_BB_Lower_Band'] = talib.BBANDS(
    df['Ask_Close'], timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
df['Ask_MACD'], df['Ask_MACD_Signal'], df['Ask_MACD_hist'] = talib.MACD(df['Ask_Close'],
                                                            fastperiod=12,
                                                            slowperiod=26,
                                                            signalperiod=9)
df['Ask_Parabollic_SAR'] = talib.SAR(df['Ask_High'], df['Ask_Low'], acceleration=0, maximum=0)
df['Ask_Slowk'], df['Ask_Slowd'] = talib.STOCH(df['Ask_High'], df['Ask_Low'], df['Ask_Close'],
                                       fastk_period=5, slowk_period=3,
                                       slowk_matype=0, slowd_period=3,
                                       slowd_matype=0)
df['Ask_RSI'] = talib.RSI(df['Ask_Close'], timeperiod=14)
df['Ask_Williams_Percent_Range'] = talib.WILLR(df['Ask_High'], df['Ask_Low'], df['Ask_Close'],
                                           timeperiod=14)
df['Ask_ADX'] = talib.ADX(df['Ask_High'], df['Ask_Low'], df['Ask_Close'], timeperiod=14)
df['Ask_ADXR'] = talib.ADXR(df['Ask_High'], df['Ask_Low'], df['Ask_Close'], timeperiod=14)
df['Ask_MOM'] = talib.MOM(df['Ask_Close'], timeperiod=10)
df['Ask_BOP'] = talib.BOP(df['Ask_Open'], df['Ask_High'], df['Ask_Low'], df['Ask_Close'])
df['Ask_AROONOSC'] = talib.AROONOSC(df['Ask_High'], df['Ask_Low'], timeperiod=14)
df['Ask_ATR'] = talib.ATR(df['Ask_High'], df['Ask_Low'], df['Ask_Close'], timeperiod=14)

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# Store the original dates in a separate column - used in the trading environment
dates = df['Date']

# Drop the original date column (it is no longer needed)
df.drop('Date', axis=1, inplace=True)

df
# Out:
#         Bid_Open  Bid_High  Bid_Low  ...   Ask_BOP  Ask_AROONOSC   Ask_ATR
# 0        0.79043   0.79080  0.78885  ... -0.400000    -28.571429  0.001883
# 1        0.78965   0.79125  0.78865  ...  0.423077    -28.571429  0.001934
# 2        0.79085   0.79168  0.78975  ... -0.310881    -28.571429  0.001934
# 3        0.79025   0.79205  0.78975  ...  0.586957    -28.571429  0.001960
# 4        0.79150   0.79195  0.78925  ... -0.740741    -28.571429  0.002013
# ...          ...       ...      ...  ...       ...           ...       ...
# 159111   0.66869   0.66871  0.66815  ... -0.947368     85.714286  0.000854
# 159112   0.66812   0.66859  0.66811  ...  0.652174     85.714286  0.000826
# 159113   0.66840   0.66840  0.66752  ... -0.655172     64.285714  0.000831
# 159114   0.66782   0.66782  0.66712  ... -0.342857     64.285714  0.000823
# 159115   0.66759   0.66766  0.66736  ...  0.029412     64.285714  0.000789
#
# [159116 rows x 87 columns]

# %% [markdown]
# ### Forex Account Details

# %%
account_balance = 5000
percent_to_risk = 0.02
pips_to_risk = 50
risk_reward_ratio = 2
n_units_per_trade = 10000
value_per_pip = n_units_per_trade * 0.0001

if ((value_per_pip * pips_to_risk) / account_balance) > percent_to_risk:
  print('To much money risked per trade -- change parameters')

pips_to_risk /= 10000

# %% [markdown]
# ### Functions for grabbing subsets of data

# %%
def create_target(dataset, i, pred_period=4):
  curr_bid_open = dataset.loc[dataset.index[i], 'Bid_Open']
  curr_ask_open = dataset.loc[dataset.index[i], 'Ask_Open']
  sell_stop_loss = curr_bid_open + pips_to_risk
  sell_stop_gain = curr_bid_open - (risk_reward_ratio * pips_to_risk)
  buy_stop_loss = curr_ask_open - pips_to_risk
  buy_stop_gain = curr_ask_open + (risk_reward_ratio * pips_to_risk)
  tmp = i
  j = 0
  buy = False
  sell = False

  # Assume a buy
  while i < dataset.shape[0] and j < pred_period:
    curr_bid_high = dataset.loc[dataset.index[i], 'Bid_High']
    curr_bid_low = dataset.loc[dataset.index[i], 'Bid_Low']

    if curr_bid_low <= buy_stop_loss:
      break

    # if curr_bid_high >= curr_ask_open + pips_to_risk:
    #   buy_stop_loss = curr_ask_open
    if curr_bid_high - pips_to_risk >= buy_stop_loss:
      buy_stop_loss = curr_bid_high - pips_to_risk

    if curr_bid_high >= buy_stop_gain:
      buy = True
      break

    i += 1
    j += 1

  i = tmp
  j = 0

  # Assume a sell
  while i < dataset.shape[0] and j < pred_period:
    curr_ask_high = dataset.loc[dataset.index[i], 'Ask_High']
    curr_ask_low = dataset.loc[dataset.index[i], 'Ask_Low']

    if curr_ask_high >= sell_stop_loss:
      break

    # if curr_ask_low <= curr_bid_open - pips_to_risk:
    #   sell_stop_loss = curr_bid_open
    if curr_ask_low + pips_to_risk <= sell_stop_loss:
      sell_stop_loss = curr_ask_low + pips_to_risk

    if curr_ask_low <= sell_stop_gain:
      sell = True
      break

    i += 1
    j += 1

  if buy and sell:
    print('wtf')
    print(i)
    print()
    return 0

  elif buy:
    return 1

  elif sell:
    return 2

  else:
    return 0

# %%
df['target'] = [create_target(df, i) for i in range(df.shape[0])]

# %%
df['target'].value_counts()
# Out:
# 0    158714
# 2       223
# 1       179
# Name: target, dtype: int64

# %%
def get_sequential_data(input_df):
    sequential_data = []
    prev_data = deque(maxlen=60)

    for i in range(input_df.shape[0] - 1):
        row = input_df.iloc[i, :]
        prev_data.append([val for val in row[:-1]])

        if len(prev_data) == 60:
          target = input_df.iloc[i + 1, -1]
          sequential_data.append([np.array(prev_data), target])

    np.random.shuffle(sequential_data)

    no_actions = []
    buys = []
    sells = []

    for seq, target in sequential_data:
        if target == 0 :
          no_actions.append([seq, np.array([1, 0, 0])])

        elif target == 1:
          buys.append([seq, np.array([0, 1, 0])])

        elif target == 2:
          sells.append([seq, np.array([0, 0, 1])])

    np.random.shuffle(no_actions)
    np.random.shuffle(buys)
    np.random.shuffle(sells)

    lower = min(len(no_actions), len(buys), len(sells))

    no_actions = no_actions[:int(lower * 1.5)]
    # buys = buys[:lower]
    # sells = sells[:lower]

    sequential_data = no_actions + buys + sells
    np.random.shuffle(sequential_data)

    return sequential_data

# %%
# training_proportion = 0.6
# train_test_cutoff_index = int(df.shape[0] * training_proportion)
# train_set = df.iloc[:train_test_cutoff_index, :]
# train_set.reset_index(drop=True, inplace=True)
# test_set = df.iloc[train_test_cutoff_index:, :]
# test_set.reset_index(drop=True, inplace=True)

# %%
# train_set['target'].value_counts()

# %%
# test_set['target'].value_counts()

# %%
# dates[df.shape[0] - 7000]
# dates[df.shape[0] - 1300]
dates[df.shape[0] - 800]
# Out:
# Timestamp('2020-09-30 03:00:00')

# %%
# test_df = df.iloc[df.shape[0] - 7000:, :]
# test_df = df.iloc[df.shape[0] - 1300:, :]
test_df = df.iloc[df.shape[0] - 800:, :]
test_df.reset_index(drop=True, inplace=True)
# df = df.iloc[0:df.shape[0] - 7000, :]
# df = df.iloc[0:df.shape[0] - 1300, :]
df = df.iloc[0:df.shape[0] - 800, :]
df.reset_index(drop=True, inplace=True)

# %%
# sequential_train_set = get_sequential_data(train_set)
# sequential_test_set = get_sequential_data(test_set)

sequential_data = get_sequential_data(df)

# %%
training_proportion = 0.7
train_test_cutoff_index = int(len(sequential_data) * training_proportion)

train_set = sequential_data[0:train_test_cutoff_index]
test_set = sequential_data[train_test_cutoff_index:]

print('Dataset shapes:')
print(len(train_set))
print(len(test_set))
# Out:
# Dataset shapes:
# 468
# 202

# %%
x_train = []
y_train = []

for seq, target in train_set:
  x_train.append(seq)
  y_train.append(target)

x_test = []
y_test = []

for seq, target in test_set:
  x_test.append(seq)
  y_test.append(target)

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# x_train = []
# y_train = []

# for seq, target in sequential_train_set:
#   x_train.append(seq)
#   y_train.append(target)

# x_test = []
# y_test = []

# for seq, target in sequential_test_set:
#   x_test.append(seq)
#   y_test.append(target)

# x_train = np.array(x_train)
# y_train = np.array(y_train)
# x_test = np.array(x_test)
# y_test = np.array(y_test)

# %%
n_sequences, n_rows, n_cols = x_train.shape
scaler = StandardScaler()

x_train = x_train.reshape(-1, n_cols)
x_train = scaler.fit_transform(x_train)
x_train = x_train.reshape(-1, n_rows, n_cols)

x_test = x_test.reshape(-1, n_cols)
x_test = scaler.transform(x_test)
x_test = x_test.reshape(-1, n_rows, n_cols)

dump(scaler, open(file_path + 'rnn/scalers/nzd_usd_rnn_scaler.pkl', 'wb'))

# %% [markdown]
# ### Training

# %%
# Hyperparameters
n_epochs = 100
batch_size = 32

# %%
# RNN
eur_usd_rnn = Sequential()

eur_usd_rnn.add(GRU(128, return_sequences=True))
eur_usd_rnn.add(Dropout(0.2))
eur_usd_rnn.add(BatchNormalization())

eur_usd_rnn.add(GRU(128, return_sequences=True))
eur_usd_rnn.add(Dropout(0.1))
eur_usd_rnn.add(BatchNormalization())

eur_usd_rnn.add(GRU(128))
eur_usd_rnn.add(Dropout(0.2))
eur_usd_rnn.add(BatchNormalization())

eur_usd_rnn.add(Dense(32, activation='relu'))
eur_usd_rnn.add(Dropout(0.2))

eur_usd_rnn.add(Dense(3, activation='softmax'))

# %%
early_stop = EarlyStopping(monitor='val_accuracy', verbose=1, patience=100)
model_checkpoint = ModelCheckpoint(file_path + 'rnn/rnns/nzd_usd_rnn.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
optimizer = Adam()

eur_usd_rnn.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = eur_usd_rnn.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=n_epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, model_checkpoint]
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1995 - accuracy: 0.4573
# Epoch 00001: val_accuracy improved from -inf to 0.49505, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 4s 250ms/step - loss: 1.1995 - accuracy: 0.4573 - val_loss: 1.0110 - val_accuracy: 0.4950
# Epoch 2/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9913 - accuracy: 0.5321
# Epoch 00002: val_accuracy improved from 0.49505 to 0.57426, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 209ms/step - loss: 0.9913 - accuracy: 0.5321 - val_loss: 0.9434 - val_accuracy: 0.5743
# Epoch 3/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8380 - accuracy: 0.6111
# Epoch 00003: val_accuracy did not improve from 0.57426
# 15/15 [==============================] - 3s 201ms/step - loss: 0.8380 - accuracy: 0.6111 - val_loss: 0.9292 - val_accuracy: 0.5347
# Epoch 4/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.6004
# Epoch 00004: val_accuracy did not improve from 0.57426
# 15/15 [==============================] - 3s 201ms/step - loss: 0.8265 - accuracy: 0.6004 - val_loss: 0.9003 - val_accuracy: 0.5693
# Epoch 5/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7738 - accuracy: 0.6538
# Epoch 00005: val_accuracy improved from 0.57426 to 0.63366, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 225ms/step - loss: 0.7738 - accuracy: 0.6538 - val_loss: 0.8660 - val_accuracy: 0.6337
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.6624
# Epoch 00006: val_accuracy did not improve from 0.63366
# 15/15 [==============================] - 3s 200ms/step - loss: 0.7437 - accuracy: 0.6624 - val_loss: 0.8621 - val_accuracy: 0.5941
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.6902
# Epoch 00007: val_accuracy did not improve from 0.63366
# 15/15 [==============================] - 3s 201ms/step - loss: 0.6797 - accuracy: 0.6902 - val_loss: 0.8360 - val_accuracy: 0.6287
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6185 - accuracy: 0.7350
# Epoch 00008: val_accuracy improved from 0.63366 to 0.68317, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 209ms/step - loss: 0.6185 - accuracy: 0.7350 - val_loss: 0.7356 - val_accuracy: 0.6832
# Epoch 9/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.7222
# Epoch 00009: val_accuracy did not improve from 0.68317
# 15/15 [==============================] - 3s 203ms/step - loss: 0.5983 - accuracy: 0.7222 - val_loss: 0.9168 - val_accuracy: 0.5792
# Epoch 10/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5987 - accuracy: 0.7393
# Epoch 00010: val_accuracy did not improve from 0.68317
# 15/15 [==============================] - 3s 207ms/step - loss: 0.5987 - accuracy: 0.7393 - val_loss: 0.7719 - val_accuracy: 0.6782
# Epoch 11/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5474 - accuracy: 0.7650
# Epoch 00011: val_accuracy did not improve from 0.68317
# 15/15 [==============================] - 3s 203ms/step - loss: 0.5474 - accuracy: 0.7650 - val_loss: 0.7973 - val_accuracy: 0.6634
# Epoch 12/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.8098
# Epoch 00012: val_accuracy improved from 0.68317 to 0.73267, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 221ms/step - loss: 0.4900 - accuracy: 0.8098 - val_loss: 0.6925 - val_accuracy: 0.7327
# Epoch 13/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4563 - accuracy: 0.7970
# Epoch 00013: val_accuracy did not improve from 0.73267
# 15/15 [==============================] - 3s 200ms/step - loss: 0.4563 - accuracy: 0.7970 - val_loss: 0.7368 - val_accuracy: 0.6931
# Epoch 14/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4336 - accuracy: 0.8184
# Epoch 00014: val_accuracy did not improve from 0.73267
# 15/15 [==============================] - 3s 211ms/step - loss: 0.4336 - accuracy: 0.8184 - val_loss: 0.7925 - val_accuracy: 0.7129
# Epoch 15/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.8291
# Epoch 00015: val_accuracy did not improve from 0.73267
# 15/15 [==============================] - 3s 201ms/step - loss: 0.4153 - accuracy: 0.8291 - val_loss: 0.7112 - val_accuracy: 0.7030
# Epoch 16/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8397
# Epoch 00016: val_accuracy did not improve from 0.73267
# 15/15 [==============================] - 3s 201ms/step - loss: 0.3923 - accuracy: 0.8397 - val_loss: 0.6973 - val_accuracy: 0.7178
# Epoch 17/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8632
# Epoch 00017: val_accuracy improved from 0.73267 to 0.73762, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 220ms/step - loss: 0.3541 - accuracy: 0.8632 - val_loss: 0.7228 - val_accuracy: 0.7376
# Epoch 18/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.8782
# Epoch 00018: val_accuracy did not improve from 0.73762
# 15/15 [==============================] - 3s 197ms/step - loss: 0.3249 - accuracy: 0.8782 - val_loss: 0.7968 - val_accuracy: 0.7030
# Epoch 19/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8761
# Epoch 00019: val_accuracy improved from 0.73762 to 0.76733, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 210ms/step - loss: 0.3262 - accuracy: 0.8761 - val_loss: 0.7711 - val_accuracy: 0.7673
# Epoch 20/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8825
# Epoch 00020: val_accuracy improved from 0.76733 to 0.77723, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 208ms/step - loss: 0.3251 - accuracy: 0.8825 - val_loss: 0.7598 - val_accuracy: 0.7772
# Epoch 21/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9038
# Epoch 00021: val_accuracy did not improve from 0.77723
# 15/15 [==============================] - 3s 203ms/step - loss: 0.2565 - accuracy: 0.9038 - val_loss: 0.8856 - val_accuracy: 0.7228
# Epoch 22/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.8889
# Epoch 00022: val_accuracy did not improve from 0.77723
# 15/15 [==============================] - 3s 220ms/step - loss: 0.2850 - accuracy: 0.8889 - val_loss: 0.7702 - val_accuracy: 0.7673
# Epoch 23/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9380
# Epoch 00023: val_accuracy improved from 0.77723 to 0.79208, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 4s 258ms/step - loss: 0.2149 - accuracy: 0.9380 - val_loss: 0.8253 - val_accuracy: 0.7921
# Epoch 24/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2007 - accuracy: 0.9167
# Epoch 00024: val_accuracy did not improve from 0.79208
# 15/15 [==============================] - 3s 225ms/step - loss: 0.2007 - accuracy: 0.9167 - val_loss: 0.9360 - val_accuracy: 0.7525
# Epoch 25/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9423
# Epoch 00025: val_accuracy did not improve from 0.79208
# 15/15 [==============================] - 3s 219ms/step - loss: 0.1731 - accuracy: 0.9423 - val_loss: 0.8078 - val_accuracy: 0.7822
# Epoch 26/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9594
# Epoch 00026: val_accuracy did not improve from 0.79208
# 15/15 [==============================] - 3s 232ms/step - loss: 0.1467 - accuracy: 0.9594 - val_loss: 0.7674 - val_accuracy: 0.7921
# Epoch 27/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9573
# Epoch 00027: val_accuracy improved from 0.79208 to 0.80693, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 4s 257ms/step - loss: 0.1416 - accuracy: 0.9573 - val_loss: 0.7950 - val_accuracy: 0.8069
# Epoch 28/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9637
# Epoch 00028: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 207ms/step - loss: 0.1333 - accuracy: 0.9637 - val_loss: 0.9316 - val_accuracy: 0.7921
# Epoch 29/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9466
# Epoch 00029: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 204ms/step - loss: 0.1769 - accuracy: 0.9466 - val_loss: 0.9513 - val_accuracy: 0.7921
# Epoch 30/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9295
# Epoch 00030: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 203ms/step - loss: 0.1985 - accuracy: 0.9295 - val_loss: 0.9101 - val_accuracy: 0.7871
# Epoch 31/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9423
# Epoch 00031: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 207ms/step - loss: 0.1913 - accuracy: 0.9423 - val_loss: 0.8654 - val_accuracy: 0.8069
# Epoch 32/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9444
# Epoch 00032: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 204ms/step - loss: 0.1464 - accuracy: 0.9444 - val_loss: 0.9736 - val_accuracy: 0.7673
# Epoch 33/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9402
# Epoch 00033: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 199ms/step - loss: 0.1659 - accuracy: 0.9402 - val_loss: 0.7944 - val_accuracy: 0.7921
# Epoch 34/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9188
# Epoch 00034: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 201ms/step - loss: 0.2075 - accuracy: 0.9188 - val_loss: 1.1141 - val_accuracy: 0.7574
# Epoch 35/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9444
# Epoch 00035: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 202ms/step - loss: 0.1467 - accuracy: 0.9444 - val_loss: 0.9383 - val_accuracy: 0.8020
# Epoch 36/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9637
# Epoch 00036: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 206ms/step - loss: 0.1207 - accuracy: 0.9637 - val_loss: 0.8821 - val_accuracy: 0.7921
# Epoch 37/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9615
# Epoch 00037: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 202ms/step - loss: 0.1154 - accuracy: 0.9615 - val_loss: 1.0735 - val_accuracy: 0.7871
# Epoch 38/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9487
# Epoch 00038: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 201ms/step - loss: 0.1149 - accuracy: 0.9487 - val_loss: 0.9104 - val_accuracy: 0.7921
# Epoch 39/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9573
# Epoch 00039: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 198ms/step - loss: 0.1397 - accuracy: 0.9573 - val_loss: 0.8362 - val_accuracy: 0.8020
# Epoch 40/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9765
# Epoch 00040: val_accuracy did not improve from 0.80693
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0806 - accuracy: 0.9765 - val_loss: 0.9509 - val_accuracy: 0.7772
# Epoch 41/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9765
# Epoch 00041: val_accuracy improved from 0.80693 to 0.81683, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 223ms/step - loss: 0.0811 - accuracy: 0.9765 - val_loss: 0.9586 - val_accuracy: 0.8168
# Epoch 42/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9744
# Epoch 00042: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0680 - accuracy: 0.9744 - val_loss: 0.9117 - val_accuracy: 0.8119
# Epoch 43/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9744
# Epoch 00043: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0746 - accuracy: 0.9744 - val_loss: 0.9803 - val_accuracy: 0.8168
# Epoch 44/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9808
# Epoch 00044: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0718 - accuracy: 0.9808 - val_loss: 1.1992 - val_accuracy: 0.7525
# Epoch 45/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9744
# Epoch 00045: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0834 - accuracy: 0.9744 - val_loss: 1.0206 - val_accuracy: 0.7772
# Epoch 46/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9765
# Epoch 00046: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0941 - accuracy: 0.9765 - val_loss: 0.9195 - val_accuracy: 0.7921
# Epoch 47/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9551
# Epoch 00047: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 202ms/step - loss: 0.1253 - accuracy: 0.9551 - val_loss: 1.3598 - val_accuracy: 0.7327
# Epoch 48/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9615
# Epoch 00048: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 204ms/step - loss: 0.1174 - accuracy: 0.9615 - val_loss: 0.9525 - val_accuracy: 0.7970
# Epoch 49/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9701
# Epoch 00049: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 203ms/step - loss: 0.1011 - accuracy: 0.9701 - val_loss: 1.0257 - val_accuracy: 0.7871
# Epoch 50/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9786
# Epoch 00050: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 201ms/step - loss: 0.0724 - accuracy: 0.9786 - val_loss: 1.0674 - val_accuracy: 0.7970
# Epoch 51/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9808
# Epoch 00051: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0791 - accuracy: 0.9808 - val_loss: 1.0019 - val_accuracy: 0.8119
# Epoch 52/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9658
# Epoch 00052: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.1250 - accuracy: 0.9658 - val_loss: 0.9928 - val_accuracy: 0.7970
# Epoch 53/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9701
# Epoch 00053: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0934 - accuracy: 0.9701 - val_loss: 1.0258 - val_accuracy: 0.8069
# Epoch 54/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9829
# Epoch 00054: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 1.1855 - val_accuracy: 0.7772
# Epoch 55/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9808
# Epoch 00055: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0478 - accuracy: 0.9808 - val_loss: 1.0794 - val_accuracy: 0.7822
# Epoch 56/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9872
# Epoch 00056: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0413 - accuracy: 0.9872 - val_loss: 1.1589 - val_accuracy: 0.7871
# Epoch 57/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9872
# Epoch 00057: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0448 - accuracy: 0.9872 - val_loss: 1.0062 - val_accuracy: 0.8119
# Epoch 58/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9915
# Epoch 00058: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 1.1193 - val_accuracy: 0.7822
# Epoch 59/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9957
# Epoch 00059: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0163 - accuracy: 0.9957 - val_loss: 1.2115 - val_accuracy: 0.8020
# Epoch 60/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9829
# Epoch 00060: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0482 - accuracy: 0.9829 - val_loss: 1.2065 - val_accuracy: 0.7426
# Epoch 61/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9850
# Epoch 00061: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0726 - accuracy: 0.9850 - val_loss: 1.1870 - val_accuracy: 0.7574
# Epoch 62/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9829
# Epoch 00062: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 4s 242ms/step - loss: 0.0499 - accuracy: 0.9829 - val_loss: 1.3070 - val_accuracy: 0.7822
# Epoch 63/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9893
# Epoch 00063: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 221ms/step - loss: 0.0428 - accuracy: 0.9893 - val_loss: 1.2325 - val_accuracy: 0.7624
# Epoch 64/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9893
# Epoch 00064: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0356 - accuracy: 0.9893 - val_loss: 1.2499 - val_accuracy: 0.7921
# Epoch 65/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9872
# Epoch 00065: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0422 - accuracy: 0.9872 - val_loss: 1.1822 - val_accuracy: 0.7772
# Epoch 66/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9957
# Epoch 00066: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0217 - accuracy: 0.9957 - val_loss: 1.0848 - val_accuracy: 0.7970
# Epoch 67/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9893
# Epoch 00067: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 204ms/step - loss: 0.0274 - accuracy: 0.9893 - val_loss: 1.2080 - val_accuracy: 0.8020
# Epoch 68/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9936
# Epoch 00068: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0321 - accuracy: 0.9936 - val_loss: 1.2520 - val_accuracy: 0.7723
# Epoch 69/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9915
# Epoch 00069: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 207ms/step - loss: 0.0210 - accuracy: 0.9915 - val_loss: 1.3052 - val_accuracy: 0.7921
# Epoch 70/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9936
# Epoch 00070: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 203ms/step - loss: 0.0367 - accuracy: 0.9936 - val_loss: 1.3418 - val_accuracy: 0.7624
# Epoch 71/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9829
# Epoch 00071: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0418 - accuracy: 0.9829 - val_loss: 1.2982 - val_accuracy: 0.7723
# Epoch 72/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9850
# Epoch 00072: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0606 - accuracy: 0.9850 - val_loss: 1.2879 - val_accuracy: 0.7871
# Epoch 73/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9722
# Epoch 00073: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0869 - accuracy: 0.9722 - val_loss: 1.2369 - val_accuracy: 0.7723
# Epoch 74/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9530
# Epoch 00074: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.1746 - accuracy: 0.9530 - val_loss: 1.0769 - val_accuracy: 0.7772
# Epoch 75/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9594
# Epoch 00075: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 205ms/step - loss: 0.0994 - accuracy: 0.9594 - val_loss: 1.0108 - val_accuracy: 0.7871
# Epoch 76/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9786
# Epoch 00076: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 211ms/step - loss: 0.0700 - accuracy: 0.9786 - val_loss: 1.0640 - val_accuracy: 0.8020
# Epoch 77/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9722
# Epoch 00077: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0627 - accuracy: 0.9722 - val_loss: 1.2119 - val_accuracy: 0.8069
# Epoch 78/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9893
# Epoch 00078: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0396 - accuracy: 0.9893 - val_loss: 1.1547 - val_accuracy: 0.7921
# Epoch 79/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9850
# Epoch 00079: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0542 - accuracy: 0.9850 - val_loss: 1.1230 - val_accuracy: 0.8069
# Epoch 80/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9893
# Epoch 00080: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0470 - accuracy: 0.9893 - val_loss: 1.2574 - val_accuracy: 0.7822
# Epoch 81/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9872
# Epoch 00081: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0499 - accuracy: 0.9872 - val_loss: 1.1770 - val_accuracy: 0.8020
# Epoch 82/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9872
# Epoch 00082: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 207ms/step - loss: 0.0451 - accuracy: 0.9872 - val_loss: 1.4220 - val_accuracy: 0.7624
# Epoch 83/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9722
# Epoch 00083: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 201ms/step - loss: 0.0807 - accuracy: 0.9722 - val_loss: 1.4990 - val_accuracy: 0.7574
# Epoch 84/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9850
# Epoch 00084: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0347 - accuracy: 0.9850 - val_loss: 1.3461 - val_accuracy: 0.7970
# Epoch 85/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9679
# Epoch 00085: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0831 - accuracy: 0.9679 - val_loss: 1.1992 - val_accuracy: 0.7921
# Epoch 86/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9615
# Epoch 00086: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 197ms/step - loss: 0.1518 - accuracy: 0.9615 - val_loss: 1.3317 - val_accuracy: 0.7624
# Epoch 87/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9679
# Epoch 00087: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 200ms/step - loss: 0.0702 - accuracy: 0.9679 - val_loss: 1.2050 - val_accuracy: 0.7970
# Epoch 88/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9893
# Epoch 00088: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0316 - accuracy: 0.9893 - val_loss: 1.1546 - val_accuracy: 0.7871
# Epoch 89/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9872
# Epoch 00089: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 199ms/step - loss: 0.0326 - accuracy: 0.9872 - val_loss: 1.1652 - val_accuracy: 0.8119
# Epoch 90/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9915
# Epoch 00090: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0193 - accuracy: 0.9915 - val_loss: 1.2495 - val_accuracy: 0.8119
# Epoch 91/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9915
# Epoch 00091: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0279 - accuracy: 0.9915 - val_loss: 1.2947 - val_accuracy: 0.7822
# Epoch 92/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9936
# Epoch 00092: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 196ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 1.2070 - val_accuracy: 0.7921
# Epoch 93/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9936
# Epoch 00093: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0212 - accuracy: 0.9936 - val_loss: 1.2496 - val_accuracy: 0.7772
# Epoch 94/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9936
# Epoch 00094: val_accuracy did not improve from 0.81683
# 15/15 [==============================] - 3s 196ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 1.1629 - val_accuracy: 0.8069
# Epoch 95/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9936
# Epoch 00095: val_accuracy improved from 0.81683 to 0.82178, saving model to /content/drive/My Drive/Forex_Robot/rnn/rnns/nzd_usd_rnn.h5
# 15/15 [==============================] - 3s 214ms/step - loss: 0.0158 - accuracy: 0.9936 - val_loss: 1.1805 - val_accuracy: 0.8218
# Epoch 96/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.82178
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.2934 - val_accuracy: 0.8020
# Epoch 97/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9979
# Epoch 00097: val_accuracy did not improve from 0.82178
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 1.3037 - val_accuracy: 0.8020
# Epoch 98/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.82178
# 15/15 [==============================] - 3s 198ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.2813 - val_accuracy: 0.8020
# Epoch 99/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.82178
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.2497 - val_accuracy: 0.7921
# Epoch 100/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.82178
# 15/15 [==============================] - 3s 197ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2711 - val_accuracy: 0.7921

# %%
eur_usd_rnn = load_model(file_path + 'rnn/rnns/nzd_usd_rnn.h5')

# %%
test_df = test_df.iloc[:, 0:-1]

# %%
scaler = load(open(file_path + 'rnn/scalers/nzd_usd_rnn_scaler.pkl', 'rb'))
test_df = scaler.transform(test_df)

# %%
test_df.shape
# Out:
# (800, 87)

# %%
test_df_sequences = deque(maxlen=60)

for i in range(0, 60):
  test_df_sequences.append(test_df[i, :])

reward = 0
n_wins = 0
n_losses = 0
win_streak = 0
loss_streak = 0
curr_win_streak = 0
curr_loss_streak = 0
n_buys = 0
n_sells = 0
trade_len = 0
trade_len_divider = 2 * 24
trade_lens = []
longest_trade = 0
trade = None
open_price = None
stop_gain = None
stop_loss = None

for i in range(60, test_df.shape[0]):
  if account_balance + reward < 0:
    print(account_balance + reward)
    
  curr_seq = np.array(test_df_sequences)
  bid_open, bid_high, bid_low, bid_close, ask_open, ask_high, ask_low, ask_close = test_df[i, 0:8]

  if trade is None:
    pred = eur_usd_rnn.predict(curr_seq.reshape(1, 60, 87))
    argmax = np.argmax(pred)
    proba = pred[0][argmax]

    if argmax == 1 and proba >= 0.6:
      trade = 'buy'
      open_price = float(round(ask_open, 5))
      stop_gain = round(open_price + (risk_reward_ratio * pips_to_risk), 5)
      stop_loss = round(open_price - pips_to_risk, 5)
      n_buys += 1

    elif argmax == 2 and proba >= 0.6:
      trade = 'sell'
      open_price = float(round(bid_open, 5))
      stop_gain = round(open_price - (risk_reward_ratio * pips_to_risk), 5)
      stop_loss = round(open_price + pips_to_risk, 5)
      n_sells += 1

  test_df_sequences.append(test_df[i, :])

  if trade is not None:
    trade_len += 1
    if trade == 'buy':
      if bid_low <= stop_loss:
        loss_amount = (stop_loss - open_price) * 10000 * value_per_pip
        # if loss_amount > 0:
        #   print('here1')
        #   print(loss_amount)
        #   break
        reward += loss_amount
        n_days = math.floor(trade_len / trade_len_divider)
        reward -= 0.8 * n_days
        n_losses += 1 if loss_amount < 0 else 0
        curr_loss_streak += 1 if loss_amount < 0 else 0
        curr_win_streak = 0
        loss_streak = max(loss_streak, curr_loss_streak)

        trade = None
        trade_lens.append(trade_len)
        longest_trade = max(longest_trade, trade_len)
        trade_len = 0

        continue

      # if bid_high >= open_price + pips_to_risk:
      #   stop_loss = open_price
      if bid_high - pips_to_risk >= stop_loss:
        stop_loss = bid_high - pips_to_risk

      if bid_high >= stop_gain:
        win_amount = (stop_gain - open_price) * 10000 * value_per_pip
        if win_amount < 0:
          print('here2')
          print(win_amount)
          break
        reward += win_amount
        n_days = math.floor(trade_len / trade_len_divider)
        reward -= 0.8 * n_days
        n_wins += 1
        curr_loss_streak = 0
        curr_win_streak += 1
        win_streak = max(win_streak, curr_win_streak)

        trade = None
        trade_lens.append(trade_len)
        longest_trade = max(longest_trade, trade_len)
        trade_len = 0

        continue

    elif trade == 'sell':
      if ask_high >= stop_loss:
        loss_amount = (open_price - stop_loss) * 10000 * value_per_pip
        # if loss_amount > 0:
        #   print('here3')
        #   print(loss_amount)
        #   break
        reward += loss_amount
        n_days = math.floor(trade_len / trade_len_divider)
        reward -= 0.8 * n_days
        n_losses += 1 if loss_amount < 0 else 0
        curr_loss_streak += 1 if loss_amount < 0 else 0
        curr_win_streak = 0
        loss_streak = max(loss_streak, curr_loss_streak)

        trade = None
        trade_lens.append(trade_len)
        longest_trade = max(longest_trade, trade_len)
        trade_len = 0

        continue

      # if ask_low <= open_price - pips_to_risk:
      #   stop_loss = open_price
      if ask_low + pips_to_risk <= stop_loss:
        stop_loss = ask_low + pips_to_risk

      if ask_low <= stop_gain:
        win_amount = (open_price - stop_gain) * 10000 * value_per_pip
        if win_amount < 0:
          print('here4')
          print(win_amount)
          break
        reward += win_amount
        n_days = math.floor(trade_len / trade_len_divider)
        reward -= 0.8 * n_days
        n_wins += 1
        curr_loss_streak = 0
        curr_win_streak += 1
        win_streak = max(win_streak, curr_win_streak)

        trade = None
        trade_lens.append(trade_len)
        longest_trade = max(longest_trade, trade_len)
        trade_len = 0

        continue

# %%
print('Number of wins: ' + str(n_wins))
print('Number of losses: ' + str(n_losses))
print('Longest win streak: ' + str(win_streak))
print('Longest loss streak: ' + str(loss_streak))
print('Buys: ' + str(n_buys))
print('Sells: ' + str(n_sells))
print('Total trades: ' + str(n_buys + n_sells))
print('Average trade length: ' + str(sum(trade_lens) / len(trade_lens)))
print('Longest trade length: ' + str(longest_trade))
print('Reward: $' + str(reward))
# Out:
# Number of wins: 4
# Number of losses: 0
# Longest win streak: 4
# Longest loss streak: 0
# Buys: 0
# Sells: 4
# Total trades: 4
# Average trade length: 9.0
# Longest trade length: 13
# Reward: $399.9999999999992
